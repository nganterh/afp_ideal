# %% [markdown]
# <h1 align='center'>AFP Ideal</h1>
#
# Considerar que el APV-A tiene un límite de bonificación de 6 UTM anuales. Este beneficio viene dado por el estado y es un 15% del dinero aportado a los ahorros. Revisar si es preferible el régimen A o B de acuerdo al sueldo, buscando los tramos imponibles en https://www.sii.cl/valores_y_fechas/impuesto_2da_categoria/impuesto2023.htm

# %%
from bs4 import BeautifulSoup
from datetime import datetime
from io import StringIO
import pandas as pd
import re
import requests



fecha_nacimiento = datetime.strptime('1994-03-01', '%Y-%m-%d')
edad_de_jubilacion = 65

salario_liquido = 2500000
salario_bruto = 2983813
monto_ahorrado = 5018141

# %%
url = r'https://www.spensiones.cl/apps/rentabilidad/getRentabilidad.php?tiprent=FP'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html.parser')

# Create a list of tables looking for class 'table'
tables = soup.find_all('table', {'class': 'table'})

# Dictionary by fund type and name
dict_returns = {'Fondo A': {'CAPITAL': None, 'CUPRUM': None, 'HABITAT': None, 'MODELO': None, 'PLANVITAL': None, 'PROVIDA': None, 'UNO': None, 'SISTEMA': None}, 
                'Fondo B': {'CAPITAL': None, 'CUPRUM': None, 'HABITAT': None, 'MODELO': None, 'PLANVITAL': None, 'PROVIDA': None, 'UNO': None, 'SISTEMA': None}, 
                'Fondo C': {'CAPITAL': None, 'CUPRUM': None, 'HABITAT': None, 'MODELO': None, 'PLANVITAL': None, 'PROVIDA': None, 'UNO': None, 'SISTEMA': None}, 
                'Fondo D': {'CAPITAL': None, 'CUPRUM': None, 'HABITAT': None, 'MODELO': None, 'PLANVITAL': None, 'PROVIDA': None, 'UNO': None, 'SISTEMA': None}, 
                'Fondo E': {'CAPITAL': None, 'CUPRUM': None, 'HABITAT': None, 'MODELO': None, 'PLANVITAL': None, 'PROVIDA': None, 'UNO': None, 'SISTEMA': None}}

# Fill the dictionary with the values from each fund for 'Últimos 12 meses Dic 2022-Nov 2023'
for table in tables[1:]:
    # Convert the HTML string to a StringIO object
    html_string = str(table)
    html_data = StringIO(html_string)
    df = pd.read_html(html_data)[0]

    # Capture the fund type using re from the first column
    match = re.search(r'TIPO ([A-E])', df.columns[0][0])
    fund_type = match.group(1) if match else None

    if fund_type:
        fund_name = f"Fondo {fund_type}"
        # Set the first column as the index
        df.set_index(df.columns[0], inplace=True)

        for afp in df.index:
            if afp in dict_returns[fund_name].keys():
                dict_returns[fund_name][afp] = df.loc[afp, df.columns[2]]
                
df_returns = pd.DataFrame(dict_returns)
df_returns
# Out:
#           Fondo A Fondo B Fondo C Fondo D Fondo E
# CAPITAL    -3,42%  -2,05%  -2,54%  -3,98%  -4,32%
# CUPRUM     -3,04%  -1,89%  -2,44%  -3,74%  -4,29%
# HABITAT    -2,97%  -1,86%  -2,53%  -4,21%  -4,77%
# MODELO     -2,79%  -1,78%  -2,16%  -3,73%  -4,34%
# PLANVITAL  -2,92%  -1,69%  -2,39%  -3,93%  -4,55%
# PROVIDA    -3,66%  -2,49%  -3,33%  -4,47%  -4,86%
# UNO        -2,90%  -1,99%  -2,44%  -3,81%  -4,38%
# SISTEMA    -3,18%  -1,99%  -2,67%  -4,16%  -4,54%

# %%
df_returns_enriched = df_returns.copy()

# Convert all values from a string like '1,23%' to a float like 0.0123
for column in df_returns_enriched.columns:
    df_returns_enriched[column] = df_returns_enriched[column].str.replace('%', '')\
        .str.replace(',', '.').astype(float) / 100

# %%
comisiones = {'CAPITAL': 0.0144, 'CUPRUM': 0.0144, 'HABITAT': 0.0127, 'MODELO': 0.0058,
              'PLANVITAL': 0.0116, 'PROVIDA': 0.0145, 'UNO': 0.0049}

df_returns_enriched
# Out:
#            Fondo A  Fondo B  Fondo C  Fondo D  Fondo E
# CAPITAL    -0.0342  -0.0205  -0.0254  -0.0398  -0.0432
# CUPRUM     -0.0304  -0.0189  -0.0244  -0.0374  -0.0429
# HABITAT    -0.0297  -0.0186  -0.0253  -0.0421  -0.0477
# MODELO     -0.0279  -0.0178  -0.0216  -0.0373  -0.0434
# PLANVITAL  -0.0292  -0.0169  -0.0239  -0.0393  -0.0455
# PROVIDA    -0.0366  -0.0249  -0.0333  -0.0447  -0.0486
# UNO        -0.0290  -0.0199  -0.0244  -0.0381  -0.0438
# SISTEMA    -0.0318  -0.0199  -0.0267  -0.0416  -0.0454

# %%
dict_calc = {afp: {'Fondo': None, 'Comisión %': None, 'Rentabilidad %': None,
                   'Comisiones': None, 'Rentabilidad': None, 'Saldo': None}
                   for afp in comisiones.keys()}

for afp, calc in dict_calc.items():
    # Find the best results for this AFP
    best_results = max(df_returns_enriched.loc[afp])

    # Find the column for the max value of each row
    best_fund = df_returns_enriched.loc[afp].idxmax()

    calc['Fondo'] = best_fund
    calc['Comisión %'] = comisiones[afp]
    calc['Rentabilidad %'] = best_results

    # Next 3 months projection
    calc['Comisiones'] = (comisiones[afp] * salario_bruto) * 3

    rent_01 = best_results * monto_ahorrado
    rent_02 = best_results * (monto_ahorrado + rent_01)
    rent_03 = best_results * (monto_ahorrado + rent_01 + rent_02)
    calc['Rentabilidad'] = rent_01 + rent_02 + rent_03

    calc['Saldo'] = calc['Rentabilidad'] - calc['Comisiones']

    # Transpose the following dataframe
df_decide = pd.DataFrame(dict_calc)

# Transpose the dataframe
df_decide = df_decide.T

df_decide.sort_values(by='Saldo', ascending=False)
# Out:
#              Fondo Comisión % Rentabilidad %   Comisiones   Rentabilidad  \
# MODELO     Fondo B     0.0058        -0.0178   51918.3462 -263227.187087
# UNO        Fondo B     0.0049        -0.0199   43862.0511 -293660.861605
# PLANVITAL  Fondo B     0.0116        -0.0169  103836.6924 -250144.276555
# HABITAT    Fondo B     0.0127        -0.0186  113683.2753 -274836.330634
# CUPRUM     Fondo B     0.0144        -0.0189  128900.7216  -279184.88308
# CAPITAL    Fondo B     0.0144        -0.0205  128900.7216 -302332.282146
# PROVIDA    Fondo B     0.0145        -0.0249  129795.8655 -365598.711206
#
#                    Saldo
# MODELO    -315145.533287
# UNO       -337522.912705
# PLANVITAL -353980.968955
# HABITAT   -388519.605934
# CUPRUM     -408085.60468
# CAPITAL   -431233.003746
# PROVIDA   -495394.576706

# %%
# Transpose the following dataframe
df_decide = pd.DataFrame(dict_calc)

# Transpose the dataframe
df_decide = df_decide.T

df_decide.to_excel('decide.xlsx')

# %%
url = r'https://www.spensiones.cl/portal/institucional/594/w3-article-2810.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html.parser')

# Create a list of tables looking for class 'table'
table = soup.find_all('li')
table

# # Read the first table as a pandas dataframe
# df = pd.read_html(str(table))
# Out:
# [<li class="pnid-581 cid-31"><a href="w3-propertyname-581.html">QuiÃ©nes Somos</a></li>,
#  <li class="current pnid-639 cid-31"><a href="w3-propertyname-639.html">EducaciÃ³n Previsional</a></li>,
#  <li class="pnid-579 cid-19"><a href="w3-propertyname-579.html">FiscalizaciÃ³n y RegulaciÃ³n</a></li>,
#  <li class="pnid-621 cid-25"><a href="w3-propertyname-621.html">EstadÃ­sticas e Informes</a></li>,
#  <li><a class="dropdown-toggle collapsed ntgBootstrap data-target_#trbuscador aria-expanded_true data-toggle_collapse" href="javascript:void(0);">
#  <span class="fa fa-search"></span><span class="fa fa-times-circle-o"></span><span class="sr-only">Buscar</span></a>
#  <div class="collapse panel panel-body" id="trbuscador">
#  <!-- Buscador -->
#  <div class="input-group input-group-lg buscador">
#  <input class="form-control placefÂ¿holder-in-title" id="keywords" name="keywords" size="30" title="Buscar" type="text" value=""/>
#  <script type="text/javascript">
#                var src="https://www.spensiones.cl/portal/institucional/594/w3-search.html";
#              </script>
#  <span class="input-group-btn">
#  <button class="btn btn-info" id="boton_busqueda" name="boton_buscador" onclick="javascript:return doSearch(src,31)" type="button">
#  <span class="fa fa-search fa-lg"></span><span class="sr-only">buscar</span>
#  </button>
#  </span>
#  <script src="https://www.spensiones.cl/portal/institucional/594/channels-31_js_buscar.js" type="text/javascript"></script>
#  <!-- Fin Buscador -->
#  </div>
#  </div>
#  </li>,
#  <li><a href="https://www.spensiones.cl/portal/institucional/594/w3-propertyvalue-9969.html">
#  <span class="fa fa-envelope-o"></span><span class="sr-only">Contacto</span></a>
#  </li>,
#  <li style="text-align: justify; ">AFP Capital: 1,44%</li>,
#  <li style="text-align: justify; ">AFP Cuprum: 1,44%</li>,
#  <li style="text-align: justify; ">AFP Habitat: 1,27%</li>,
#  <li style="text-align: justify; ">AFP Modelo: 0,58%</li>,
#  <li style="text-align: justify; ">AFP Planvital: 1,16%</li>,
#  <li style="text-align: justify; ">AFP Provida: 1,45%</li>,
#  <li style="text-align: justify; ">AFP Uno: 0,49%</li>,
#  <li style="text-align: justify; ">Para saber cuÃ¡nto le cobra su AFP por administrar sus ahorros previsionales use la <a href="/apps/costoPrevisional/formCalculoCostoPrevisional.php">Calculadora del Costo Previsional</a>.</li>,
#  <li style="text-align: justify; ">Para comparar la comisiÃ³n, servicio y temas como la rentabilidad que ofrecen las AFP use el <a href="/infoafp">InfÃ³rmate y Decide</a>.</li>,
#  <li class="aid-10100 cid-17"><a href="w3-article-10100.html">Â¿Las y los trabajadores independientes estÃ¡n cubiertos por el Seguro de Invalidez y Sobrevivencia (SIS)?</a></li>,
#  <li class="aid-2838 cid-17"><a href="w3-article-2838.html">Â¿Puedo elegir cualquier tipo de fondo?</a></li>,
#  <li class="aid-8451 cid-17"><a href="w3-article-8451.html">Â¿QuiÃ©n supervisa a las y los asesores previsionales?</a></li>,
#  <li class="aid-3569 cid-17"><a href="w3-article-3569.html">Soy una persona pensionada, pero sigo trabajando Â¿debo pagar cotizaciones?</a></li>,
#  <li class="aid-8041 cid-17"><a href="w3-article-8041.html">Â¿QuÃ© instituciones pueden administrar el Ahorro Previsional Voluntario (APV)?</a></li>,
#  <li class="aid-2748 cid-17"><a href="w3-article-2748.html">Â¿CÃ³mo puede una persona saber si le corresponde algÃºn beneficio del Pilar Solidario?</a></li>,
#  <li class="aid-2816 cid-17"><a href="w3-article-2816.html">Â¿QuÃ© cotizaciones se registran en las cuentas de capitalizaciÃ³n individual?</a></li>,
#  <li class="aid-2955 cid-17"><a href="w3-article-2955.html">Â¿QuiÃ©nes tienen cobertura del SIS?</a></li>,
#  <li class="aid-2723 cid-17"><a href="w3-article-2723.html">Â¿CÃ³mo se determina el monto a cotizar de las y los trabajadores independientes?</a></li>,
#  <li class="aid-8048 cid-17"><a href="w3-article-8048.html">Â¿QuÃ© es la licitaciÃ³n de la administraciÃ³n de cuentas de nuevas y nuevos afiliados?</a></li>,
#  <li class="aid-2732 cid-17"><a href="w3-article-2732.html">Â¿A quiÃ©n le corresponde efectuar la cobranza de cotizaciones impagas?</a></li>,
#  <li class="aid-2724 cid-17"><a href="w3-article-2724.html">Â¿QuiÃ©nes no tienen obligaciÃ³n de cotizar como trabajadora o trabajador independiente?</a></li>,
#  <li class="aid-2823 cid-17"><a href="w3-article-2823.html">Â¿Una persona pensionada del antiguo sistema, hoy afiliada a una AFP, puede retirar sus fondos?</a></li>,
#  <li class="aid-2815 cid-17"><a href="w3-article-2815.html">Â¿CÃ³mo puedo saber quÃ© comisiÃ³n me cobra mi AFP?</a></li>,
#  <li class="aid-8437 cid-17"><a href="w3-article-8437.html">Â¿Puedo retirar el dinero de mi cuenta antes de pensionarme?</a></li>,
#  <li class="aid-3566 cid-17"><a href="w3-article-3566.html">Â¿QuÃ© debe hacer la o el empleador si estÃ¡ atrasado en el pago de las cotizaciones de sus trabajadoras y trabajadores?</a></li>,
#  <li class="aid-2903 cid-17"><a href="w3-article-2903.html">Â¿CuÃ¡nto tiempo se puede adelantar la jubilaciÃ³n por trabajos pesados?</a></li>,
#  <li class="aid-2908 cid-17"><a href="w3-article-2908.html">Â¿En quÃ© consiste el Ahorro Previsional Voluntario (APV) y la Cuenta de Ahorro Voluntario (Cuenta 2) ?</a></li>,
#  <li class="aid-10312 cid-17"><a href="w3-article-10312.html">Â¿CuÃ¡les son las obligaciones de las y los asesores previsionales y de las entidades de asesorÃ­a previsional?</a></li>,
#  <li class="aid-2818 cid-17"><a href="w3-article-2818.html">Â¿CuÃ¡l es la diferencia entre el sistema de AFP y el sistema antiguo o de reparto?</a></li>,
#  <li class="aid-3575 cid-17"><a href="w3-article-3575.html">Â¿CuÃ¡les son los requisitos para obtener una pensiÃ³n anticipada si cotizo por trabajos pesados?</a></li>,
#  <li class="aid-8021 cid-17"><a href="w3-article-8021.html">Â¿Tienen acceso al Pilar Solidario las personas del antiguo sistema de pensiones?</a></li>,
#  <li class="aid-3790 cid-17"><a href="w3-article-3790.html">Â¿Puedo cotizar en mÃ¡s de una AFP?</a></li>,
#  <li class="aid-7975 cid-17"><a href="w3-article-7975.html">Â¿QuÃ© es la PensiÃ³n Autofinanciada de Referencia (PAFE)?</a></li>,
#  <li class="aid-2728 cid-17"><a href="w3-article-2728.html">Â¿CuÃ¡l es el plazo para pagar las cotizaciones previsionales?</a></li>,
#  <li class="aid-2727 cid-17"><a href="w3-article-2727.html">Â¿DÃ³nde y cÃ³mo se pagan las cotizaciones?</a></li>,
#  <li class="aid-2912 cid-17"><a href="w3-article-2912.html">Â¿La AFP cobra comisiones por administrar la Cuenta de Ahorro Voluntario o Cuenta 2?</a></li>,
#  <li class="aid-2817 cid-17"><a href="w3-article-2817.html">Â¿A quiÃ©n pertenecen los recursos acumulados en la AFP?</a></li>,
#  <li class="aid-2726 cid-17"><a href="w3-article-2726.html">Â¿QuÃ© pasa si una persona que trabaja a honorarios cotiza tambiÃ©n como dependiente?</a></li>,
#  <li class="aid-2905 cid-17"><a href="w3-article-2905.html">Â¿QuÃ© es la Cuenta de Ahorro Voluntario o Cuenta 2?</a></li>,
#  <li class="aid-10109 cid-17"><a href="w3-article-10109.html">Â¿Todas las personas que trabajan de manera independiente estÃ¡n obligadas a cotizar?</a></li>,
#  <li><a href="w3-article-12825.html"><span class="fa fa-map-marker"></span> Oficinas</a></li>,
#  <li><a href="w3-propertyvalue-9971.html"><span class="fa fa-newspaper-o"></span> Prensa</a></li>,
#  <li><a href="w3-propertyvalue-10118.html"><span class="fa fa-info-circle"></span> English overview</a></li>,
#  <li><a href="rss3-channel.rss"><span class="fa fa-rss"></span> RSS</a></li>,
#  <li><a href="https://twitter.com/Superpensiones"><span class="fa fa-twitter"></span> SÃ­ganos en Twitter </a></li>,
#  <li><a href="/apps/admusuarioswww/loginUsuario.php"><span class="fa fa-lock"></span>Usuarios registrados</a></li>,
#  <li><a href="/apps/tea/indexTEA.php"><span class="fa fa-info-circle"></span>Transferencia electrÃ³nica de archivos</a></li>,
#  <li><a href="w3-article-3917.html">Certificado del sitio</a></li>,
#  <li><a href="w3-article-3915.html">PolÃ­tica de privacidad</a></li>,
#  <li><a href="w3-article-7983.html">Visualizadores</a></li>,
#  <li><a href="w3-contents.html">Mapa del sitio</a></li>]
